# %% [markdown]
# # 02 - Integración
#
# Flujo mínimo de integración MCP.

# %% [markdown]
# ## Paso 1
#
# Listar -> elegir -> leer schema -> validar.

# %%
from pathlib import Path
import json

# Ajusta esta ruta según tu entorno.
# En Cursor suele existir una carpeta con descriptores MCP en ~/.cursor/projects/.../mcps
base = Path.home() / ".cursor"

print("Ruta base candidata:", base)
print("¿Existe?", base.exists())

# Tip: usa esto como punto de partida para ubicar tus descriptores MCP.
# Out:
# Ruta base candidata: /Users/guane/.cursor
# ¿Existe? True

# %%
# Ejemplo: leer un descriptor de herramienta (si ya conoces la ruta)
# descriptor_path = Path("/ruta/a/mcps/<server>/tools/<tool>.json")

example_descriptor = {
    "name": "search_issues",
    "description": "Busca issues en un tracker",
    "inputSchema": {
        "type": "object",
        "properties": {
            "query": {"type": "string"},
            "limit": {"type": "integer", "minimum": 1, "maximum": 100},
        },
        "required": ["query"],
    },
}

print(json.dumps(example_descriptor, indent=2, ensure_ascii=False))
# Out:
# {
#   "name": "search_issues",
#   "description": "Busca issues en un tracker",
#   "inputSchema": {
#     "type": "object",
#     "properties": {
#       "query": {
#         "type": "string"
#       },
#       "limit": {
#         "type": "integer",
#         "minimum": 1,
#         "maximum": 100
#       }
#     },
#     "required": [
#       "query"
#     ]
#   }
# }

# %% [markdown]
# ## Paso 2
#
# Tool -> args -> validar -> invocar -> manejar error.

# %% [markdown]
# ## Ejercicio
#
# Identifica: requerido, error y validación.
